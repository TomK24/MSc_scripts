# %%
import seaborn as sns
import pandas
import numpy as np
import matplotlib.pyplot as plt

df = pandas.read_csv("lig_rmsd_all.csv", sep=',')
sns.set_style("whitegrid")
plt.figure(figsize=(80, 12))
my_pal = {"PZA": "m", "SANC00110": "y", "SANC00112": "b", "SANC00117": "b", "SANC00128": "b", "SANC00129": "y", "SANC00136": "b", "SANC00167": "b", "SANC00170": "b", "SANC00182": "y", "SANC00193": "b", "SANC00202": "y", "SANC00231": "b", "SANC00237": "y", "SANC00238_le": "b", "SANC00238_lc": "y", "SANC00239": "b", "SANC00240": "b", "SANC00241": "b", "SANC00242": "b", "SANC00243": "y", "SANC00244": "b", "SANC00245": "b", "SANC00253": "b", "SANC00258": "b", "SANC00267": "b", "SANC00268": "b", "SANC00287": "b", "SANC00307": "b", "SANC00308": "y", "SANC00309": "b", "SANC00312": "b", "SANC00313_le": "b", "SANC00313_lc": "y", "SANC00315": "y", "SANC00318": "y", "SANC00319": "b", "SANC00320": "b", "SANC00321": "b", "SANC00322": "b", "SANC00332": "b", "SANC00333": "b", "SANC00336_le": "b", "SANC00336_lc": "b", "SANC00343": "b", "SANC00351": "y", "SANC00360": "b", "SANC00361": "b", "SANC00362": "b", "SANC00363": "y", "SANC00441": "b", "SANC00471": "b", "SANC00520": "b", "SANC00521": "y", "SANC00523": "b", "SANC00527": "b", "SANC00529": "b", "SANC00563": "b", "SANC00565": "b", "SANC00570": "b", "SANC00604": "b", "SANC00611_le": "b", "SANC00611_lc": "b", "SANC00613": "b", "SANC00614": "y", "SANC00615": "b", "SANC00626": "b", "SANC00628": "b", "SANC00635": "b", "SANC00639": "b", "SANC00643": "b", "SANC00644": "b", "SANC00648": "y", "SANC00651": "b", "SANC00652": "y", "SANC00679_le": "b", "SANC00679_lc": "b", "SANC00683_le": "y", "SANC00683_lc": "b", "SANC00688": "b", "SANC00704": "b", "SANC00710": "b", "SANC00712": "b", "SANC00719": "y"}
# Draw a violinplot with a narrower bandwidth than the default
b=sns.violinplot(x=df["Systems"], y=df["RMSD (nm)"], inner="quartile",  width=1, palette=my_pal)
#sns.set(font_scale = 2)
#b.set_yticklabels(b.get_yticklabels(), size = 15, rotation=90)
b.set_ylabel("RMSD (nm)",fontsize=35)
b.set_xlabel("Systems",fontsize=40)
b.set_xticklabels(b.get_xticklabels(), size = 12, rotation=90)
b.tick_params(labelsize=35)
plt.ylim(0.0, 0.8)
plt.tight_layout()
plt.savefig('lig_rmsd_wide2.png', format='png', dpi=150, bbox_inches='tight')
